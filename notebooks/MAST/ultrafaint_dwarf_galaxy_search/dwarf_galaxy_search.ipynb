# %% [markdown]
# # Learning Goals
#
# By the end of this tutorial you will: <br>
# * Learn to search a survey for observations of a known target.
# * Be able to plot a color-magnitude diagram.
# * Use coordinates to plot a spectrum of a known member in a dwarf galaxy.

# %% [markdown]
# # Introduction
#
# There are a number of dwarf galaxies that are gravitationally bound to the Milky Way. These satellites are small and generally faint companions in the Local Group that are not observable with the naked eye, except for the Large and Small Magenllanic Cloud. A vast majority of these satellites are known as Dwarf spheroidal galaxies [Metz et al. 2018](https://ui.adsabs.harvard.edu/abs/2007MNRAS.376..387M/abstract), and we will explote ways to analyze a dwarf spheroidal galaxy in this notebook.
#
# We will be searching the [Pan-STARRS](https://outerspace.stsci.edu/display/PANSTARRS/) (PS1) catalog for data on an already discovered dwarf galaxy. The methods we use in this notebook can be extended to find new dwarf galaxies but in this application we will be using the MAST archive and its tools to search PS1 for data on an already known target. To choose our target, we will be referencing the paper "Milky Way Satellite Census. I. The Observational Selection Function for Milky Way Satellites in DES Y3 and Pan-STARRS DR1" by [Drlica-Wagner et al. 2020](https://iopscience.iop.org/article/10.3847/1538-4357/ab7eb9).
#
# After searching PS1 for data on our target, we will use the data to plot a color-magnitude diagram of the galaxy and also plot an image of the field of view of our target. Next, we will choose another target, repeat the steps of gathering PS1 data, and compare both target's color-magnitude diagrams. Lastly, we will search Hubble Space Telescope data to plot a spectral image of our first target.

# %% [markdown]
# # Imports
#
# The following cell holds the imported packages. These packages are necessary for running the rest of the cells in this notebook. A description of each import is as follows:
#
# * numpy to handle array functions
# * Imvis and Specvis from Jdavis to show images and extract spectra
# * fits from astropy.io for accessing FITS files
# * Table from astropy.table for creating tidy tables of the data
# * ascii from astropy.io for accessing the API results
# * matplotlib.pyplot for plotting data
# * Mast, Observations, and Catalogs from astroquery.mast for querying data and observations from the MAST archive
# * requests for gathering data from the PS1 API
# * units from astropy and SkyCoord from astropy.coordinates for converting RA and Dec into degrees

# %%
#pip install jdaviz --upgrade #this cell is necessary if you have not yet installed Jdavis
# Out:
# Requirement already satisfied: jdaviz in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (2.10.0)
# Requirement already satisfied: ipygoldenlayout>=0.3.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.4.0)
# Requirement already satisfied: regions>=0.6 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.6)
# Requirement already satisfied: glue-core>=1.5.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (1.5.0)
# Requirement already satisfied: ipysplitpanes>=0.1.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.2.0)
# Requirement already satisfied: packaging in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (20.9)
# Requirement already satisfied: sidecar>=0.5.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.5.1)
# Requirement already satisfied: astropy>=4.3 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (5.1)
# Requirement already satisfied: ipyvue>=1.6 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (1.7.0)
# Requirement already satisfied: echo>=0.5.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.6)
# Requirement already satisfied: voila>=0.3.5 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.3.6)
# Requirement already satisfied: matplotlib in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (3.6.0)
# Requirement already satisfied: specreduce<1.2.0,>=1.1.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (1.1.0)
# Requirement already satisfied: asdf>=2.7.4 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (2.13.0)
# Requirement already satisfied: traitlets>=5.0.5 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (5.4.0)
# Requirement already satisfied: astroquery in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.4.6)
# Requirement already satisfied: bqplot-image-gl>=1.4.11 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (1.4.11)
# Requirement already satisfied: glue-jupyter>=0.12 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.13.0)
# Requirement already satisfied: gwcs>=0.16.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.18.2)
# Requirement already satisfied: photutils>=1.4 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (1.5.0)
# Requirement already satisfied: vispy>=0.6.5 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.11.0)
# Requirement already satisfied: idna in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (2.10)
# Requirement already satisfied: bqplot>=0.12.33 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.12.36)
# Requirement already satisfied: ipyvuetify>=1.7.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (1.8.4)
# Requirement already satisfied: ipypopout>=0.0.11 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (1.0.0)
# Requirement already satisfied: pyyaml>=5.4.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (5.4.1)
# Requirement already satisfied: scikit-image in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.18.1)
# Requirement already satisfied: specutils>=1.7.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (1.8.1)
# Requirement already satisfied: glue-astronomy>=0.5 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.5.0)
# Requirement already satisfied: asteval>=0.9.23 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jdaviz) (0.9.27)
# Requirement already satisfied: asdf-standard>=1.0.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from asdf>=2.7.4->jdaviz) (1.0.3)
# Requirement already satisfied: semantic-version>=2.8 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from asdf>=2.7.4->jdaviz) (2.10.0)
# Requirement already satisfied: jmespath>=0.6.2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from asdf>=2.7.4->jdaviz) (1.0.1)
# Requirement already satisfied: asdf-transform-schemas>=0.2.2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from asdf>=2.7.4->jdaviz) (0.3.0)
# Requirement already satisfied: jsonschema<4.10.0,>=4.0.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from asdf>=2.7.4->jdaviz) (4.9.1)
# Requirement already satisfied: numpy>=1.10 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from asdf>=2.7.4->jdaviz) (1.20.1)
# Requirement already satisfied: importlib-resources>=3 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from asdf>=2.7.4->jdaviz) (5.9.0)
# Requirement already satisfied: pyerfa>=2.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from astropy>=4.3->jdaviz) (2.0.0.1)
# Requirement already satisfied: pandas<2.0.0,>=1.0.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from bqplot>=0.12.33->jdaviz) (1.2.4)
# Requirement already satisfied: traittypes>=0.0.6 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from bqplot>=0.12.33->jdaviz) (0.2.1)
# Requirement already satisfied: ipywidgets<9,>=7.5.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from bqplot>=0.12.33->jdaviz) (8.0.2)
# Requirement already satisfied: qtpy in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from echo>=0.5.0->jdaviz) (1.9.0)
# Requirement already satisfied: spectral-cube>=0.6.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-astronomy>=0.5->jdaviz) (0.6.0)
# Requirement already satisfied: qtconsole>=4.3 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-core>=1.5.0->jdaviz) (5.0.3)
# Requirement already satisfied: h5py>=2.10 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-core>=1.5.0->jdaviz) (2.10.0)
# Requirement already satisfied: ipykernel!=5.0.0,!=5.1.0,>=4.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-core>=1.5.0->jdaviz) (5.3.4)
# Requirement already satisfied: openpyxl>=3.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-core>=1.5.0->jdaviz) (3.0.7)
# Requirement already satisfied: dill>=0.2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-core>=1.5.0->jdaviz) (0.3.5.1)
# Requirement already satisfied: pvextractor>=0.2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-core>=1.5.0->jdaviz) (0.3)
# Requirement already satisfied: ipython>=4.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-core>=1.5.0->jdaviz) (7.22.0)
# Requirement already satisfied: xlrd>=1.2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-core>=1.5.0->jdaviz) (2.0.1)
# Requirement already satisfied: scipy>=1.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-core>=1.5.0->jdaviz) (1.6.2)
# Requirement already satisfied: mpl-scatter-density>=0.7 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-core>=1.5.0->jdaviz) (0.7)
# Requirement already satisfied: setuptools>=30.3.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-core>=1.5.0->jdaviz) (52.0.0.post20210125)
# Requirement already satisfied: ipyvolume>=0.5.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-jupyter>=0.12->jdaviz) (0.5.2)
# Requirement already satisfied: notebook>=4.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-jupyter>=0.12->jdaviz) (6.3.0)
# Requirement already satisfied: glue-vispy-viewers>=1.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-jupyter>=0.12->jdaviz) (1.0.5)
# Requirement already satisfied: ipympl>=0.3.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-jupyter>=0.12->jdaviz) (0.9.2)
# Requirement already satisfied: pyopengl in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-vispy-viewers>=1.0->glue-jupyter>=0.12->jdaviz) (3.1.6)
# Requirement already satisfied: pillow in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from glue-vispy-viewers>=1.0->glue-jupyter>=0.12->jdaviz) (8.2.0)
# Requirement already satisfied: asdf-astropy>=0.2.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from gwcs>=0.16.1->jdaviz) (0.2.2)
# Requirement already satisfied: asdf-wcs-schemas in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from gwcs>=0.16.1->jdaviz) (0.1.1)
# Requirement already satisfied: asdf-coordinates-schemas in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from asdf-astropy>=0.2.0->gwcs>=0.16.1->jdaviz) (0.1.0)
# Requirement already satisfied: six in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from h5py>=2.10->glue-core>=1.5.0->jdaviz) (1.15.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from importlib-resources>=3->asdf>=2.7.4->jdaviz) (3.4.1)
# Requirement already satisfied: jupyter-client in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipykernel!=5.0.0,!=5.1.0,>=4.0->glue-core>=1.5.0->jdaviz) (6.1.12)
# Requirement already satisfied: appnope in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipykernel!=5.0.0,!=5.1.0,>=4.0->glue-core>=1.5.0->jdaviz) (0.1.2)
# Requirement already satisfied: tornado>=4.2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipykernel!=5.0.0,!=5.1.0,>=4.0->glue-core>=1.5.0->jdaviz) (6.1)
# Requirement already satisfied: ipython-genutils in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipympl>=0.3.0->glue-jupyter>=0.12->jdaviz) (0.2.0)
# Requirement already satisfied: decorator in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0->glue-core>=1.5.0->jdaviz) (5.0.6)
# Requirement already satisfied: backcall in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0->glue-core>=1.5.0->jdaviz) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0->glue-core>=1.5.0->jdaviz) (3.0.17)
# Requirement already satisfied: pexpect>4.3 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0->glue-core>=1.5.0->jdaviz) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0->glue-core>=1.5.0->jdaviz) (0.7.5)
# Requirement already satisfied: pygments in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0->glue-core>=1.5.0->jdaviz) (2.8.1)
# Requirement already satisfied: jedi>=0.16 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipython>=4.0->glue-core>=1.5.0->jdaviz) (0.17.2)
# Requirement already satisfied: pythreejs>=1.0.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipyvolume>=0.5.0->glue-jupyter>=0.12->jdaviz) (2.4.1)
# Requirement already satisfied: ipywebrtc in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipyvolume>=0.5.0->glue-jupyter>=0.12->jdaviz) (0.6.0)
# Requirement already satisfied: requests in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipyvolume>=0.5.0->glue-jupyter>=0.12->jdaviz) (2.25.1)
# Requirement already satisfied: widgetsnbextension~=4.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.12.33->jdaviz) (4.0.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets<9,>=7.5.0->bqplot>=0.12.33->jdaviz) (3.0.3)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=4.0->glue-core>=1.5.0->jdaviz) (0.7.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jsonschema<4.10.0,>=4.0.1->asdf>=2.7.4->jdaviz) (1.3.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jsonschema<4.10.0,>=4.0.1->asdf>=2.7.4->jdaviz) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jsonschema<4.10.0,>=4.0.1->asdf>=2.7.4->jdaviz) (20.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->jdaviz) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->jdaviz) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->jdaviz) (4.37.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->jdaviz) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->jdaviz) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from matplotlib->jdaviz) (0.10.0)
# Requirement already satisfied: fast-histogram>=0.3 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from mpl-scatter-density>=0.7->glue-core>=1.5.0->jdaviz) (0.11)
# Requirement already satisfied: nbformat in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->glue-jupyter>=0.12->jdaviz) (5.6.0)
# Requirement already satisfied: argon2-cffi in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->glue-jupyter>=0.12->jdaviz) (20.1.0)
# Requirement already satisfied: nbconvert in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->glue-jupyter>=0.12->jdaviz) (6.5.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->glue-jupyter>=0.12->jdaviz) (0.9.4)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->glue-jupyter>=0.12->jdaviz) (4.11.1)
# Requirement already satisfied: prometheus-client in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->glue-jupyter>=0.12->jdaviz) (0.10.1)
# Requirement already satisfied: jinja2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->glue-jupyter>=0.12->jdaviz) (3.1.2)
# Requirement already satisfied: pyzmq>=17 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->glue-jupyter>=0.12->jdaviz) (20.0.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.0->glue-jupyter>=0.12->jdaviz) (1.5.0)
# Requirement already satisfied: et-xmlfile in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from openpyxl>=3.0->glue-core>=1.5.0->jdaviz) (1.0.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from pandas<2.0.0,>=1.0.0->bqplot>=0.12.33->jdaviz) (2021.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=4.0->glue-core>=1.5.0->jdaviz) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0->glue-core>=1.5.0->jdaviz) (0.2.5)
# Requirement already satisfied: ipydatawidgets>=1.1.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from pythreejs>=1.0.0->ipyvolume>=0.5.0->glue-jupyter>=0.12->jdaviz) (4.3.2)
# Requirement already satisfied: jupyterlab<4,>=3.0.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from sidecar>=0.5.1->jdaviz) (3.0.14)
# Requirement already satisfied: nbclassic~=0.2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab<4,>=3.0.0->sidecar>=0.5.1->jdaviz) (0.2.6)
# Requirement already satisfied: jupyterlab-server~=2.3 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab<4,>=3.0.0->sidecar>=0.5.1->jdaviz) (2.4.0)
# Requirement already satisfied: jupyter-packaging~=0.7 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab<4,>=3.0.0->sidecar>=0.5.1->jdaviz) (0.7.12)
# Requirement already satisfied: jupyter-server~=1.4 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab<4,>=3.0.0->sidecar>=0.5.1->jdaviz) (1.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jinja2->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (2.1.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab<4,>=3.0.0->sidecar>=0.5.1->jdaviz) (3.6.1)
# Requirement already satisfied: websocket-client in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jupyter-server~=1.4->jupyterlab<4,>=3.0.0->sidecar>=0.5.1->jdaviz) (1.4.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab<4,>=3.0.0->sidecar>=0.5.1->jdaviz) (1.2.0)
# Requirement already satisfied: babel in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab<4,>=3.0.0->sidecar>=0.5.1->jdaviz) (2.9.0)
# Requirement already satisfied: json5 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from jupyterlab-server~=2.3->jupyterlab<4,>=3.0.0->sidecar>=0.5.1->jdaviz) (0.9.5)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (0.5.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (0.3)
# Requirement already satisfied: beautifulsoup4 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (4.9.3)
# Requirement already satisfied: lxml in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (4.6.3)
# Requirement already satisfied: tinycss2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (1.1.1)
# Requirement already satisfied: bleach in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (3.3.0)
# Requirement already satisfied: defusedxml in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (0.7.1)
# Requirement already satisfied: nest-asyncio in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbclient>=0.5.0->nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (1.5.1)
# Requirement already satisfied: async-generator in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbclient>=0.5.0->nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (1.10)
# Requirement already satisfied: fastjsonschema in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from nbformat->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (2.16.2)
# Requirement already satisfied: synphot in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from specreduce<1.2.0,>=1.1.0->jdaviz) (1.1.1)
# Requirement already satisfied: dask[array] in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from spectral-cube>=0.6.0->glue-astronomy>=0.5->jdaviz) (2021.4.0)
# Requirement already satisfied: joblib in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from spectral-cube>=0.6.0->glue-astronomy>=0.5->jdaviz) (1.0.1)
# Requirement already satisfied: casa-formats-io in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from spectral-cube>=0.6.0->glue-astronomy>=0.5->jdaviz) (0.1)
# Requirement already satisfied: radio-beam>=0.3.3 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from spectral-cube>=0.6.0->glue-astronomy>=0.5->jdaviz) (0.3.3)
# Requirement already satisfied: ndcube>=2.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from specutils>=1.7.0->jdaviz) (2.0.2)
# Requirement already satisfied: freetype-py in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from vispy>=0.6.5->jdaviz) (2.3.0)
# Requirement already satisfied: hsluv in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from vispy>=0.6.5->jdaviz) (5.0.3)
# Requirement already satisfied: websockets>=9.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from voila>=0.3.5->jdaviz) (10.3)
# Requirement already satisfied: cffi>=1.0.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (1.14.5)
# Requirement already satisfied: pycparser in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (2.20)
# Requirement already satisfied: html5lib>=0.999 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from astroquery->jdaviz) (1.1)
# Requirement already satisfied: keyring>=4.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from astroquery->jdaviz) (22.3.0)
# Requirement already satisfied: pyvo>=1.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from astroquery->jdaviz) (1.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->notebook>=4.0->glue-jupyter>=0.12->jdaviz) (2.2.1)
# Requirement already satisfied: webencodings in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from html5lib>=0.999->astroquery->jdaviz) (0.5.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from requests->ipyvolume>=0.5.0->glue-jupyter>=0.12->jdaviz) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from requests->ipyvolume>=0.5.0->glue-jupyter>=0.12->jdaviz) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from requests->ipyvolume>=0.5.0->glue-jupyter>=0.12->jdaviz) (1.26.4)
# Requirement already satisfied: fsspec>=0.6.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from dask[array]->spectral-cube>=0.6.0->glue-astronomy>=0.5->jdaviz) (0.9.0)
# Requirement already satisfied: partd>=0.3.10 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from dask[array]->spectral-cube>=0.6.0->glue-astronomy>=0.5->jdaviz) (1.2.0)
# Requirement already satisfied: toolz>=0.8.2 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from dask[array]->spectral-cube>=0.6.0->glue-astronomy>=0.5->jdaviz) (0.11.1)
# Requirement already satisfied: cloudpickle>=1.1.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from dask[array]->spectral-cube>=0.6.0->glue-astronomy>=0.5->jdaviz) (1.6.0)
# Requirement already satisfied: locket in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages/locket-0.2.1-py3.8.egg (from partd>=0.3.10->dask[array]->spectral-cube>=0.6.0->glue-astronomy>=0.5->jdaviz) (0.2.1)
# Requirement already satisfied: networkx>=2.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from scikit-image->jdaviz) (2.5)
# Requirement already satisfied: imageio>=2.3.0 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from scikit-image->jdaviz) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from scikit-image->jdaviz) (2020.10.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/emmalieb/opt/anaconda3/lib/python3.8/site-packages (from scikit-image->jdaviz) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import requests
from PIL import Image
from io import BytesIO
from jdaviz import Imviz, Specviz
from astropy.io import fits
import astropy.utils
from astropy.table import Table
from astroquery.mast import Mast, Observations, Catalogs
from astropy.io import ascii
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS

# %% [markdown]
# # Searching PS1 Data for a Known Target

# %% [markdown]
# ## Choosing a Target
#
# Using Table 2 and Table 4 from Drlica-Wagner et al. 2020, we can choose a galaxy that has PS1 data to search for. We will choose the galaxy with the brightest magnitude that has been confirmed using PS1: **Leo I**.
#
# Table 2 lists the Right Acension, Declination, and distance of **Leo I** which we will use to search the database. We can see that it's basic characteristics are:
# * Right Ascension: 152.1146 degrees
# * Declination: 12.3059 degrees
# * Distance: 254 kiloparsecs
# * M_v: −11.78
#
# ### Gather necessary parameters
#
# Table 2 lists the Right Acension, Declination, and distance of **Leo I** which we will use to search the database. Additionally, we will need the API url in order to search PS1 for this target. We are using a search radius around **Leo I** of 12 arcminutes to be sure we are looking at the entire galaxy, [SIMBAD](https://simbad.u-strasbg.fr/simbad/sim-id?Ident=leo+I&NbIdent=1&Radius=2&Radius.unit=arcmin&submit=submit+id) lists the angular size of **Leo I** as 11.5 arcminutes.

# %%
ra = "152.1146" #[deg]
dec = "12.3059" #[deg]
dist = "254" #[kpc]
radius = "0.2" #[deg] = 12 arcminutes

baseurl="https://catalogs.mast.stsci.edu/api/v0.1/panstarrs/" #this is the base url for querying the API
release = "dr1/" #you can also look at dr2 if you want
obj = "mean" #we will look at the mean photometric information for our target
condition = "nDetections.gte=1" #this condition allows us to only get data where at least 1 observation has been made
form = "csv"

# %% [markdown]
# ## Retrieve PS1 data
#
# The Panoramic Survey Telescope & Rapid Response System (Pan-STARRS) is a wide-field imaging facility developed at the University of Hawaii's Institute for Astronomy. We are going to be using the MAST API for PS1 to gather our data. Discriptions for the PS1 MeanObjectView table fields can be found here: https://outerspace.stsci.edu/display/PANSTARRS/PS1+MeanObjectView+table+fields .
#
# ### Build API URL and Get Data

# %%
#now build the url to get the data using the parameters we gathered
url = baseurl+release+obj+"?ra="+ra+"&dec="+dec+"&radius="+radius+"&"+condition+"&format="+form
print(url)

#Request data from the API
results = requests.get(url)
results = results.text

#Make a table from the results
tab = ascii.read(results)
tab[0:5]
# Out:
# https://catalogs.mast.stsci.edu/api/v0.1/panstarrs/dr1/mean?ra=152.1146&dec=12.3059&radius=0.2&nDetections.gte=1&format=csv
# <Table length=5>
#          objName           objAltName1 ... yFlags       distance
#           str26               int64    ... int64        float64
# -------------------------- ----------- ... ------ -------------------
# PSO J100752.401+121011.081        -999 ...      0 0.19743295941381817
# PSO J100752.746+121015.726        -999 ...   4112  0.1954978950638571
# PSO J100753.383+121017.557        -999 ...     24 0.19329852366853878
# PSO J100753.346+121015.741        -999 ...   4112 0.19373530817219156
# PSO J100753.522+121016.062        -999 ...   4112 0.19315876894541972

# %% [markdown]
# ## Plot Color-Magnitude Diagram (CMD) of Leo I
#
# Color-Magnitude Diagrams (CMD) are a common way astronomers visualize the photometric parameters of a stellar system. Where the stars of a system fall on a CMD can tell you things like the age of that system and therefore, what types of stars it is composed of. The colors of a system can also tell us about the tempurature of that system. Color in astronomy is defined to be the difference between the magnitudes in one filter and the magnitudes in another filter.
#
# ### Gather arrays for plotting
# A CMD consists of the magnitudes in one filter (y-axis) vs the difference between the magnitudes in that filter and the magnitudes in another filter (x-axis). For this example we will plot the magnitudes of **Leo I** in g vs the magnitude of **Leo I** in g-r. Additionally, we'll take a look at the CMD in r-i. What CMDs show is the relationship between the magnitudes of the signal we have detected in different color filters, so in this case a larger value for g (visual filter or bluer filter) minus r (red filter) means the star is redder, and a smaller g-r value means the star is bluer. A larger value in r (red) minus i (even more red) means the star is redder, and a smaller r-i value means the star is bluer. In order to plot these CMDs we will need a couple arrays:
#
# * Magnitudes in the g filter
# * Magnitudes in the r filter
# * Magnitudes in the i filter

# %%
g_mag = tab["gMeanApMag"] #mean aperture magntiude in g filter
r_mag = tab["rMeanApMag"] #mean aperture magntiude in r filter
i_mag = tab["iMeanApMag"] #mean aperture magntiude in i filter

#convert to numpy arrays for easy plotting
g_mag = np.array(g_mag)
r_mag = np.array(r_mag)
i_mag = np.array(i_mag)

#get the difference between the filters 
g_r = np.subtract(g_mag,r_mag)

#get the difference between the filters 
r_i = np.subtract(r_mag,i_mag)

# %% [markdown]
# ### Plot CMD in g - r

# %%
plt.scatter(g_r, g_mag, c = "coral", edgecolor = "black", alpha = 0.75)
plt.xlim(-5,5)
plt.ylim(28,12.5)
plt.xlabel("g - r")
plt.ylabel("g")
# Out:
# Text(0, 0.5, 'g')

# %% [markdown]
# ### Plot CMD in r - i

# %%
plt.scatter(r_i, i_mag, c = "turquoise", edgecolor = "black", alpha = 0.75)
plt.xlim(-5,5)
plt.ylim(30,10)
plt.xlabel("r - i")
plt.ylabel("i")
# Out:
# Text(0, 0.5, 'i')

# %% [markdown]
# ### Plot CMD in g-r and r-i side-by-side

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
fig.set_size_inches(10,3)

ax1.scatter(g_r, g_mag, c = "coral", edgecolor = "black", alpha = 0.75)
ax1.set_xlim(-5,5)
ax1.set_ylim(30,10)
ax1.set_xlabel("g - r")
ax1.set_ylabel("g")

ax2.scatter(r_i, i_mag, c = "turquoise", edgecolor = "black", alpha = 0.75)
ax2.set_xlim(-5,5)
ax2.set_ylim(30,10)
ax2.set_xlabel("r - i")
ax2.set_ylabel("i")
# Out:
# Text(0, 0.5, 'i')

# %% [markdown]
# ## Plot Field of View (FOV) of Leo I
#
# ### Build the url to the fits file of the region for our target by the cutout service.

# %%
filters = "grizy"
size = "3000" #extracted image size in pixels (0.25 arcsec/pixel)
form = "fits" #file format of the file we would like

color = "red" #you can change this, red is typically the i or r filter

#get the url to the PS1 images
images_url = "https://ps1images.stsci.edu/cgi-bin/ps1filenames.py?ra="+ra+"&dec="+dec+"&filters="+filters
#read the images data into a table
img_table = Table.read(images_url, format='ascii')

#get the first filename from the list of images
file = img_table['filename'][0]

#build the url to the fits file
fits_url = "https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra="+ra+"&dec="+dec+"&size="+size+"&format="+form+"&"+color+"="+file

print(fits_url)
# Out:
# https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra=152.1146&dec=12.3059&size=3000&format=fits&red=/rings.v3.skycell/1627/003/rings.v3.skycell.1627.003.stk.g.unconv.fits

# %% [markdown]
# ### Open the fits file and inspect the header
#
# Here we will plot the field of view containing our galaxy, **Leo I**. In the next step we will also show you how to convert from pixel coordinates to sky coordinates (RA and Dec), to do this we will use the information in the FITS header combined with the astropy package WCS. FITS headers contain meta-deta about the image or data cube including but not limited to: the date, time, telescope, and instrument that made the observation, the exposure time and wavelength band of the data, and the physical size and binning of the pixels in the image.

# %%
#open the fits file and get the data
fh = fits.open(fits_url)
fits_img = fh[0].data

#get the FITS header
header = fh[0].header
wcs_leoI = WCS(header)

#take a look at the FITS header
header
# Out:
# SIMPLE  =                    T / file does conform to FITS standard
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 3000 / length of data axis 1
# NAXIS2  =                 3000 / length of data axis 2
# EXTEND  =                    T / FITS dataset may contain extensions
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# DATE    = '2022-09-22T19:32:56' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# CRVAL1  =     151.363632202094
# CRVAL2  =     13.9999999999996
# CRPIX1  =              12071.5 / Reference pixel shifted for cutout
# CRPIX2  =              25888.5 / Reference pixel shifted for cutout
# CDELT1  = 6.94444461259988E-05
# CDELT2  = 6.94444461259988E-05
# PC001001=                  -1.
# PC001002=                   0.
# PC002001=                   0.
# PC002002=                   1.
# HISTORY ppStack at 2015-02-24T14:16:25.785871
# PSLIB_V = '37083   '
# HISTORY psLib version: tags/ipp-pv3-20140717/psLib@37083
# HISTORY psLib source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# MODULE_V= '37323:37768'
# HISTORY psModules version: tags/ipp-pv3-20140717/psModules@37323:37768
# HISTORY psModules source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# PHOT_V  = '37083   '
# HISTORY psphot version: tags/ipp-pv3-20140717/psphot@37083
# HISTORY psphot source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# STATS_V = '37083   '
# HISTORY ppStats version: tags/ipp-pv3-20140717/ppStats@37083
# HISTORY ppStats source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# STACK_V = '37083   '
# HISTORY ppStack version: tags/ipp-pv3-20140717/ppStack@37083
# HISTORY ppStack source: 60eb6cdc-a59c-4636-a4e0-dba66a9721fd
# NINPUTS =                   15 / Number of input images
# STK_TYPE= 'DEEP_STACK'         / type of stack
# STK_ID  = '4546160 '           / type of stack
# SKYCELL = 'skycell.1627.003'   / type of stack
# TESS_ID = 'RINGS.V3'           / type of stack
# AIRM_SLP=                   0. / airmass slope
# INP_0000= 'o5241g0221o.135261.wrp.1473646.skycell.1627.003.fits' / input image n
# INP_0001= 'o5241g0233o.135273.wrp.1473653.skycell.1627.003.fits' / input image n
# INP_0002= 'o5595g0523o.292936.wrp.1473661.skycell.1627.003.fits' / input image n
# INP_0003= 'o5595g0542o.292955.wrp.1473665.skycell.1627.003.fits' / input image n
# INP_0004= 'o5596g0479o.293545.wrp.1473669.skycell.1627.003.fits' / input image n
# INP_0005= 'o5596g0480o.293546.wrp.1473671.skycell.1627.003.fits' / input image n
# INP_0006= 'o5596g0497o.293563.wrp.1473673.skycell.1627.003.fits' / input image n
# INP_0007= 'o5596g0498o.293564.wrp.1473674.skycell.1627.003.fits' / input image n
# INP_0008= 'o5947g0545o.441055.wrp.1473677.skycell.1627.003.fits' / input image n
# INP_0009= 'o5948g0402o.441577.wrp.1473678.skycell.1627.003.fits' / input image n
# INP_0010= 'o5948g0406o.441579.wrp.1473705.skycell.1627.003.fits' / input image n
# INP_0011= 'o5948g0420o.441593.wrp.1473709.skycell.1627.003.fits' / input image n
# INP_0012= 'o5948g0424o.441597.wrp.1473710.skycell.1627.003.fits' / input image n
# INP_0013= 'o6357g0164o.587426.wrp.1473713.skycell.1627.003.fits' / input image n
# INP_0014= 'o6357g0182o.587443.wrp.1473717.skycell.1627.003.fits' / input image n
# SCL_0000=             20.06362 / input image scale factor
# SCL_0001=             20.04502 / input image scale factor
# SCL_0002=             23.98809 / input image scale factor
# SCL_0003=             24.07599 / input image scale factor
# SCL_0004=             24.48035 / input image scale factor
# SCL_0005=             24.09347 / input image scale factor
# SCL_0006=             24.31371 / input image scale factor
# SCL_0007=             24.39787 / input image scale factor
# SCL_0008=             24.66285 / input image scale factor
# SCL_0009=               24.523 / input image scale factor
# SCL_0010=                   0. / input image scale factor
# SCL_0011=             24.72089 / input image scale factor
# SCL_0012=             25.78359 / input image scale factor
# SCL_0013=             25.54401 / input image scale factor
# SCL_0014=             25.44593 / input image scale factor
# ZPT_0000=             24.52456 / input image zero point
# ZPT_0001=             24.54094 / input image zero point
# ZPT_0002=             24.50694 / input image zero point
# ZPT_0003=             24.50792 / input image zero point
# ZPT_0004=             24.51109 / input image zero point
# ZPT_0005=             24.50654 / input image zero point
# ZPT_0006=             24.51401 / input image zero point
# ZPT_0007=             24.51526 / input image zero point
# ZPT_0008=              24.4985 / input image zero point
# ZPT_0009=             24.49237 / input image zero point
# ZPT_0010=             24.50037 / input image zero point
# ZPT_0011=              24.4941 / input image zero point
# ZPT_0012=             24.49866 / input image zero point
# ZPT_0013=               24.445 / input image zero point
# ZPT_0014=             24.46045 / input image zero point
# EXP_0000=                  52. / input image exptime
# EXP_0001=                  52. / input image exptime
# EXP_0002=                  43. / input image exptime
# EXP_0003=                  43. / input image exptime
# EXP_0004=                  43. / input image exptime
# EXP_0005=                  43. / input image exptime
# EXP_0006=                  43. / input image exptime
# EXP_0007=                  43. / input image exptime
# EXP_0008=                  43. / input image exptime
# EXP_0009=                  43. / input image exptime
# EXP_0010=                  43. / input image exptime
# EXP_0011=                  43. / input image exptime
# EXP_0012=                  43. / input image exptime
# EXP_0013=                  43. / input image exptime
# EXP_0014=                  43. / input image exptime
# AIR_0000=                1.057 / input image airmass
# AIR_0001=                1.038 / input image airmass
# AIR_0002=                1.143 / input image airmass
# AIR_0003=                1.192 / input image airmass
# AIR_0004=                1.115 / input image airmass
# AIR_0005=                1.101 / input image airmass
# AIR_0006=                1.156 / input image airmass
# AIR_0007=                1.138 / input image airmass
# AIR_0008=                1.114 / input image airmass
# AIR_0009=                1.106 / input image airmass
# AIR_0010=                1.112 / input image airmass
# AIR_0011=                1.145 / input image airmass
# AIR_0012=                1.151 / input image airmass
# AIR_0013=                1.096 / input image airmass
# AIR_0014=                1.067 / input image airmass
# PSCAMERA= 'GPC1    '           / Camera name
# PSFORMAT= 'SKYCELL '           / Camera format
# IMAGEID =              4546160 / Image identifier
# SOURCEID=                   35 / Source identifier
# HIERARCH FPA.TELESCOPE = 'PS1     ' / Telescope of origin
# HIERARCH FPA.INSTRUMENT = 'GPC1    ' / Instrument name (according to the instrum
# HIERARCH FPA.DETECTOR = 'GPC1    ' / Detector name
# HIERARCH FPA.COMMENT = '        ' / Observation comment
# HIERARCH FPA.OBS.MODE = '        ' / Observation mode (eg, survey id)
# HIERARCH FPA.OBS.GROUP = '        ' / Observation group (eg, associated images)
# HIERARCH FPA.FOCUS = 'NaN     ' / Telescope focus
# AIRMASS =                   1. / Airmass at boresight
# HIERARCH FPA.FILTERID = 'g.00000 ' / Filter used (parsed, abstract name)
# HIERARCH FPA.FILTER = 'g.00000 ' / Filter used (instrument name)
# HIERARCH FPA.POSANGLE = 'NaN     ' / Position angle of instrument
# HIERARCH FPA.ROTANGLE = 'NaN     ' / Rotator angle of instrument
# HIERARCH FPA.RADECSYS = '        ' / Celestial coordinate system
# HIERARCH FPA.RA = 'NaN     '   / Right Ascension of boresight
# HIERARCH FPA.DEC = 'NaN     '  / Declination of boresight
# HIERARCH FPA.LONGITUDE = 'NaN     ' / West longitude of observatory
# HIERARCH FPA.LATITUDE = 'NaN     ' / Latitude of observatory
# HIERARCH FPA.ELEVATION = 'NaN     ' / Elevation of observatory (meters)
# HIERARCH FPA.OBSTYPE = '        ' / Type of observation
# HIERARCH FPA.OBJECT = '        ' / Object of observation
# HIERARCH FPA.ALT = 'NaN     '  / Altitude of boresight
# HIERARCH FPA.AZ = 'NaN     '   / Azimuth of boresight
# HIERARCH FPA.TEMP = 'NaN     ' / Temperature of focal plane
# HIERARCH FPA.M1X = 'NaN     '  / Primary Mirror X Position
# HIERARCH FPA.M1Y = 'NaN     '  / Primary Mirror Y Position
# HIERARCH FPA.M1Z = 'NaN     '  / Primary Mirror Z Position
# HIERARCH FPA.M1TIP = 'NaN     ' / Primary Mirror TIP
# HIERARCH FPA.M1TILT = 'NaN     ' / Primary Mirror TILT
# HIERARCH FPA.M2X = 'NaN     '  / Primary Mirror X Position
# HIERARCH FPA.M2Y = 'NaN     '  / Primary Mirror Y Position
# HIERARCH FPA.M2Z = 'NaN     '  / Primary Mirror Z Position
# HIERARCH FPA.M2TIP = 'NaN     ' / Primary Mirror TIP
# HIERARCH FPA.M2TILT = 'NaN     ' / Primary Mirror TILT
# HIERARCH FPA.ENV.TEMP = 'NaN     ' / Environment: Temperature
# HIERARCH FPA.ENV.HUMID = 'NaN     ' / Environment: Humidity
# HIERARCH FPA.ENV.WIND = 'NaN     ' / Environment: Wind speed
# HIERARCH FPA.ENV.DIR = 'NaN     ' / Environment: Wind direction
# HIERARCH FPA.TELTEMP.M1 = 'NaN     ' / Telescope Temperatures: M1
# HIERARCH FPA.TELTEMP.M1CELL = 'NaN     ' / Telescope Temperatures: M1 cell
# HIERARCH FPA.TELTEMP.M2 = 'NaN     ' / Telescope Temperatures: M2
# HIERARCH FPA.TELTEMP.SPIDER = 'NaN     ' / Telescope Temperatures: spider
# HIERARCH FPA.TELTEMP.TRUSS = 'NaN     ' / Telescope Temperatures: truss
# HIERARCH FPA.TELTEMP.EXTRA = 'NaN     ' / Telescope Temperatures: extra
# HIERARCH FPA.PON.TIME = 'NaN     ' / Power On Time
# HIERARCH FPA.ZP =          25. / Magnitude zero point
# HIERARCH CHIP.XSIZE =        0 / Size of chip (pixels)
# HIERARCH CHIP.YSIZE =        0 / Size of chip (pixels)
# HIERARCH CHIP.TEMP = 'NaN     ' / Temperature of chip
# HIERARCH CHIP.TEMPERATURE = 'NaN     ' / Temperature of chip
# HIERARCH CHIP.ID = '        '  / Chip identifier
# HIERARCH CHIP.SEEING = 'NaN     ' / Seeing FWHM (pixels)
# HIERARCH CHIP.VIDEOCELL =    F / Does this OTA have any video cells
# HIERARCH CELL.GAIN =  1.041306 / CCD gain (e/count)
# HIERARCH CELL.READNOISE = 8.318236 / CCD read noise (e)
# HIERARCH CELL.SATURATION = 670373.3 / Saturation level (counts)
# HIERARCH CELL.BAD =         0. / Bad level (counts)
# EXPTIME =                 663. / Exposure time (sec)
# HIERARCH CELL.DARKTIME = 'NaN     ' / Time since flush (sec)
# HIERARCH CELL.XBIN =         1 / Binning in x
# HIERARCH CELL.YBIN =         1 / Binning in y
# MJD-OBS =     55754.8772327505 / Time of exposure
# HIERARCH CELL.XSIZE =        0 / Size of cell (pixels)
# HIERARCH CELL.YSIZE =        0 / Size of cell (pixels)
# HIERARCH CELL.XWINDOW =      0 / Start of cell window (pixels)
# HIERARCH CELL.YWINDOW =      0 / Start of cell window (pixels)
# HIERARCH CELL.TRIMSEC = '[1:6242,1:6254]' / Trim section
# HIERARCH CELL.BIASSEC = ''
# HISTORY Created by fitscut 1.4.2 (William Jon McCann)
# RADESYS = 'FK5     '           / added by fitscut
# TIMESYS = 'TAI     '           / added by fitscut

# %% [markdown]
# ### Plot the Field of View image

# %%
# replace NaN values with zero for display
fits_img[np.isnan(fits_img)] = 0.0

#make figure
fig = plt.figure(figsize = (10, 10))
#this subplot with the "projection" keyword will put our axes into units of RA and Dec
ax = plt.subplot(projection = wcs_leoI)
plt.imshow(fits_img, origin = 'lower', cmap = 'Greys_r', aspect = 'equal', vmin = 0, vmax = 255)
plt.xlabel('RA')
plt.ylabel('Dec')
plt.xlim(400,3000)
# Out:
# (400.0, 3000.0)

# %% [markdown]
# ### Build the url to the color image file of the region for our target

# %%
size = "3000" #extracted image size in pixels (0.25 arcsec/pixel) = 12.5 arcminutes of angular size
form = "png" #file format of the file we would like, for color images it has to be a jpeg or png
filters = "yig"
red = "red"

#build the PS1 url for the color image
color_img_url = "https://ps1images.stsci.edu/cgi-bin/ps1filenames.py?ra="+ra+"&dec="+dec+"&filters="+filters
color_img_table = Table.read(color_img_url, format='ascii')
color_file = color_img_table['filename'][0]
color_png_url = "https://ps1images.stsci.edu/cgi-bin/fitscut.cgi?ra="+ra+"&dec="+dec+"&size="+size+"&format="+form

#now we need to get all three colors (r,g,b)
for i, param in enumerate(["red","green","blue"]):
            color_png_url = color_png_url + "&{}={}".format(param,color_img_table['filename'][i])

# %% [markdown]
# ### Plot the FOV in Color

# %%
#open the url and get the image
r = requests.get(color_png_url)
im = Image.open(BytesIO(r.content))
#make figure
fig = plt.figure(figsize = (10, 10))
#this subplot with the "projection" keyword will put our axes into units of RA and Dec
ax = plt.subplot(projection = wcs_leoI)
#plot the image
plt.imshow(im, origin = 'lower', aspect = 'equal',vmin=0, vmax = 255) 
plt.xlabel(r'RA')
plt.ylabel(r'Dec')
plt.xlim(400,3000)
# Out:
# (400.0, 3000.0)

# %% [markdown]
# # Repeat with New Target and Compare
#
# Now we will repeat the same process for a new target, **Draco II** and compare it with **Leo I**.
#
# ## Retrieve PS1 data
# This is the same method as before, just using the position of **Draco II** instead. You can find the RA and Dec of **Draco II** in Table I of its discovery paper, [Laevens et al 2015](https://iopscience.iop.org/article/10.1088/0004-637X/813/1/44 ). It is also listed on [SIMBAD](https://simbad.u-strasbg.fr/simbad/sim-id?Ident=draco+ii&NbIdent=1&Radius=2&Radius.unit=arcmin&submit=submit+id).

# %%
#read RA and Dec from either SIMBAD or Table 1 in Laevens et al 2015
r = '15:52:47.6'
d = '+64:33:55'
form = "csv"
radius = "0.1"

#Convert the RA and Dec to degrees
c = SkyCoord(r+d, unit=(u.hourangle, u.deg))
draco_ra = str(c.ra.degree)
draco_dec = str(c.dec.degree)

#now build the url to get the data from using the parameters we gathered
draco_url = baseurl+release+obj+"?ra="+draco_ra+"&dec="+draco_dec+"&radius="+radius+"&"+condition+"&format="+form
print(draco_url)

#Request data from the API
draco_results = requests.get(draco_url)
draco_results = draco_results.text

#Make a table from the results
draco_tab = ascii.read(draco_results)
draco_tab[0:5]
# Out:
# https://catalogs.mast.stsci.edu/api/v0.1/panstarrs/dr1/mean?ra=238.1983333333333&dec=64.56527777777778&radius=0.1&nDetections.gte=1&format=csv
# <Table length=5>
#          objName           objAltName1 ... yFlags       distance
#           str26               int64    ... int64        float64
# -------------------------- ----------- ... ------ -------------------
# PSO J155209.404+643743.423        -999 ... 115000 0.09319959594004266
# PSO J155210.801+643807.389        -999 ...   4120 0.09612685273723748
# PSO J155211.846+643753.765        -999 ...   4112 0.09210038630122991
# PSO J155212.176+643758.080        -999 ...      0 0.09255856075784266
# PSO J155211.484+643802.987        -999 ...      0 0.09439174127771656

# %% [markdown]
# ## Plot CMDs of Draco II
#
# Gather the arrays for plotting the color-magnitude diagrams using the same method as before.

# %%
draco_g_mag = draco_tab["gMeanApMag"] #mean aperture magntiude in g filter
draco_r_mag = draco_tab["rMeanApMag"] #mean aperture magntiude in r filter
draco_i_mag = draco_tab["iMeanApMag"] #mean aperture magntiude in i filter

#convert to numpy arrays for easy plotting
draco_g_mag = np.array(draco_g_mag)
draco_r_mag = np.array(draco_r_mag)
draco_i_mag = np.array(draco_i_mag)

#get the difference between the filters 
draco_g_r = np.subtract(draco_g_mag,draco_r_mag)
draco_r_i = np.subtract(draco_r_mag,draco_i_mag)

# %% [markdown]
# ### Plot CMD in g-r and r-i side-by-side

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
fig.set_size_inches(10,3)

ax1.scatter(draco_g_r, draco_g_mag, c = "gold", edgecolor = "black", alpha = 0.75)
ax1.set_xlim(-5,5)
ax1.set_ylim(30,10)
ax1.set_xlabel("g - r")
ax1.set_ylabel("g")

ax2.scatter(draco_r_i, draco_i_mag, c = "dodgerblue", edgecolor = "black", alpha = 0.75)
ax2.set_xlim(-5,5)
ax2.set_ylim(30,10)
ax2.set_xlabel("r - i")
ax2.set_ylabel("i")
# Out:
# Text(0, 0.5, 'i')

# %% [markdown]
# ## Let's overplot the CMDs for Leo I and Draco II
#
# To compare the compositions of **Leo I** and **Draco II**, we can plot their Color-Magnitude Diagrams on top of each other to see how they differ. As before, we will first plot a CMD in g-r vs g and then in r-i vs i.

# %%
plt.scatter(g_r, g_mag, c = "coral", label = "Leo I", edgecolor = "black", alpha = 0.75)
plt.scatter(draco_g_r, draco_g_mag, c = "gold", label = "Draco II", edgecolor = "black", alpha = 0.75)
plt.xlim(-5,5)
plt.ylim(30,10)
plt.xlabel("g - r")
plt.ylabel("g")
plt.legend()

# %%
plt.scatter(r_i, i_mag, c = "turquoise", label = "Leo I", edgecolor = "black", alpha = 0.75)
plt.scatter(draco_r_i, draco_i_mag, c = "dodgerblue", label = "Draco II", edgecolor = "black", alpha = 0.75)
plt.xlim(-5,5)
plt.ylim(30,10)
plt.xlabel("r - i")
plt.ylabel("i")
plt.legend()

# %% [markdown]
# # Plot Spectral Image for a Member of Leo I
#
# We can use the paper [Kirby et al. 2010 ](https://ui.adsabs.harvard.edu/abs/2010ApJS..191..352K/abstract) to find an individual member of **Leo I**. From here we can use the coordinates of a member, search the MAST archive for observations of it, and plot its spectrum.
#
# Let's take a look at member **LeoI72134** by Kirby et al. 2010, we are choosing this star because it has multiple citations so we should be able to learn a lot about it.
#
# ### Convert RA and Dec to Degrees
#
# The coordinates from Kirby et al. 2010 are in units of hour angle while the MAST archive needs units of degrees, so we will have to convert the coordinates.

# %%
#Get the RA and Dec
ra = "10 08 01.88"
dec = "+12 17 55.5" 

#Convert the RA and Dec into degrees
c = SkyCoord(ra+dec, unit=(u.hourangle, u.deg))
ra = str(c.ra.deg)
dec = str(c.dec.deg)
print(ra,dec)
# Out:
# 152.0078333333333 12.29875

# %% [markdown]
# ### First, Query MAST Archive for HST observations of LeoI72134

# %%
hst_table = Observations.query_criteria(coordinates = ra+dec,radius="0.5 deg", dataproduct_type="spectrum", obs_collection="HST")

#Let's print out some relevant columns of this table
hst_table["instrument_name","filters","target_name","obs_id","calib_level","t_exptime"]
# Out:
# <Table length=2>
# instrument_name filters target_name   obs_id  calib_level t_exptime
#      str13        str5      str9       str9      int64     float64
# --------------- ------- ----------- --------- ----------- ---------
#   STIS/NUV-MAMA   G230L   1007+0042 o8ex88010           3    2400.0
#   STIS/NUV-MAMA   G230L   1007+0042 o8ex22010           3    2331.0

# %% [markdown]
# ### Now, we have to select observations for a specific instrument and filter combination
#
# This is made easy by the fact that there is only 1 filter/instrument combination for this object in the HST catalog. That is: G230L, let's look at the observations for that mode. Additionally, we will look at the observation with the longest exposure time, so we will select that observation at this step as well.

# %%
g230L_table = hst_table['obsid','obs_id','target_name','calib_level',
                        't_exptime','filters','em_min','em_max'][hst_table['filters']=='G230L']

sel_table = g230L_table[np.argmin(g230L_table['t_exptime'])]
sel_table
# Out:
# <Row index=1>
#  obsid     obs_id  target_name calib_level t_exptime filters  em_min  em_max
#   str8      str9       str9       int64     float64    str5  float64 float64
# -------- --------- ----------- ----------- --------- ------- ------- -------
# 24946556 o8ex22010   1007+0042           3    2331.0   G230L   157.0   318.0

# %% [markdown]
# ### Get the Minimum Recommended Products for this observation
#
# Now, we will query the observations from MAST to get a list of products for our selected observation. Then, we will gather the minimum recommended products needed in order to plot a spectrum. This step is necessary as HST specifically can provide more data than is needed to plot the spectrum of our observation.

# %%
data_products = Observations.get_product_list(sel_table)

wprod = np.where((data_products['productGroupDescription']=='Minimum Recommended Products') & 
                 (data_products['productType']=='SCIENCE'))[0]

data_products[wprod]
# Out:
# <Table masked=True length=1>
#  obsID   obs_collection dataproduct_type ... parent_obsid dataRights calib_level
#   str8        str3            str8       ...     str8        str6       int64
# -------- -------------- ---------------- ... ------------ ---------- -----------
# 24946556            HST         spectrum ...     24946556     PUBLIC           2

# %% [markdown]
# ### Download the data to plot

# %%
data = Observations.download_products(data_products[wprod])

data
# Out:
# INFO: Found cached file ./mastDownload/HST/o8ex22010/o8ex22010_flt.fits with expected size 10535040. [astroquery.query]
# <Table length=1>
#                    Local Path                    Status  Message  URL
#                      str47                        str8    object object
# ----------------------------------------------- -------- ------- ------
# ./mastDownload/HST/o8ex22010/o8ex22010_flt.fits COMPLETE    None   None

# %% [markdown]
# ### Next, we will investigate the FITS file we just downloaded

# %%
filename = data['Local Path'][0]
hdulist = fits.open(filename)

header = hdulist[0].header
scidata = hdulist[1].data

# %% [markdown]
# ### Plot the Spectral Image
#
# Now, finally, we can plot the data using Matplotlib. The spectral image of a member of **Leo I** shown here is a 2-dimensional spectral image. The next step could be to extract a spectrum (flux vs wavelength) from this image, and that is left to the user.

# %%
fig = plt.
plt.imshow(scidata, cmap="CMRmap")
plt.ylim(600,450)
plt.xlabel("x pixels")
plt.ylabel("y pixels")
# Out:
# Text(0, 0.5, 'y pixels')

# %% [markdown]
# # Exercise
#
# ## 1. Plot Field of View of Draco II
#
# Can you recreate the steps we took for **Leo I** to plot the field of view of **Draco II** in black and white and in color?

# %% [markdown]
# # About this Notebook
#
# **Author:** Emma Lieb <br>
# **Last Updated:** Sept 2022

# %% [markdown]
# # Citations
#
# * [Citation for `astropy`](https://www.astropy.org/acknowledging.html)
